# %% [markdown]
# <a href="https://colab.research.google.com/github/Vasanth731/basic_ml_alg/blob/main/algorithm_grad_decent.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
X = np.random.rand(50,1)
y = 2*X + 1 + 0.1*(np.random.rand(50,1))

# %%
print(y)
# Out:
# [[2.97248999]
#  [2.65391853]
#  [2.0959992 ]
#  [2.38599307]
#  [2.24614725]
#  [2.50598038]
#  [1.81073864]
#  [1.92234581]
#  [1.25696514]
#  [2.78267284]
#  [1.8814048 ]
#  [2.1646291 ]
#  [1.82053778]
#  [1.22398945]
#  [2.08655486]
#  [1.69303233]
#  [1.71463377]
#  [1.33459864]
#  [1.85579061]
#  [1.50674262]
#  [2.53783087]
#  [1.68505057]
#  [2.4371008 ]
#  [1.57031833]
#  [2.74681222]
#  [1.87857039]
#  [2.41934024]
#  [2.06440089]
#  [1.69106993]
#  [1.63672452]
#  [1.44269652]
#  [2.66034747]
#  [1.93530211]
#  [2.28467106]
#  [2.08627149]
#  [1.17187603]
#  [1.41324662]
#  [1.98454832]
#  [2.20981936]
#  [3.00431955]
#  [2.38037961]
#  [2.56132406]
#  [2.23990688]
#  [2.94834098]
#  [1.67881246]
#  [1.4289645 ]
#  [2.50327218]
#  [1.17200415]
#  [2.8460334 ]
#  [1.1564312 ]]

# %%
plt.plot(X,y,'.')

# %%
w_new = np.random.rand()
b_new = np.random.rand()
y_pred = w_new * X + b_new

# %%
plt.plot(X,y,'.')
plt.plot(X,y_pred)

# %%
lr = 0.1
errors = []
for i in range(100):
  ypred = w_new*X + b_new

  error = (y - ypred)
  errors.extend(error)

  db_new = - 2 * error.mean()
  dw_new = - 2 * (X*error).mean()

  b_new = b_new - lr * db_new
  w_new = w_new - lr * dw_new

  if i % 5 == 0:
    plt.figure(figsize=(10,8))
    plt.plot(X,y,'.')
    plt.plot(X, w_new*X + b_new)
    plt.show()

# %%
print(w_new, b_new)
# Out:
# 1.5357144585829179 1.2906336228861568
